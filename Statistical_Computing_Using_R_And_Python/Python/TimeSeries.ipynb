# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('stock_data - stock_data.csv',parse_dates=True,index_col='Date')

# %%
df.head()
# Out:
#             Unnamed: 0   Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03         NaN  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04         NaN  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05         NaN  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06         NaN  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09         NaN  43.10  43.66  42.82  43.42  16268338  AABA

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA

# %%
df['Volume'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot(subplots=True,figsize=(16,9))
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
df_month = df[df.columns[:5]].resample('M').mean()

# %%
df_month.head(10)
# Out:
#                  Open       High        Low      Close        Volume
# Date
# 2006-01-31  38.245500  38.694000  37.641500  38.113000  3.400594e+07
# 2006-02-28  33.141579  33.436842  32.627368  32.975789  2.329848e+07
# 2006-03-31  31.333478  31.696957  30.929130  31.218696  2.095522e+07
# 2006-04-30  32.383684  32.790000  31.914737  32.283158  2.200768e+07
# 2006-05-31  31.744545  32.175455  31.171364  31.517273  2.218047e+07
# 2006-06-30  31.005455  31.380455  30.619545  30.981818  1.599786e+07
# 2006-07-31  29.893500  30.334000  29.452500  29.890500  3.137006e+07
# 2006-08-31  28.064348  28.445652  27.769565  28.132174  1.293729e+07
# 2006-09-30  27.481000  27.734000  26.966000  27.256500  2.599914e+07
# 2006-10-31  24.528636  24.865000  24.172273  24.537727  3.671393e+07

# %%
fig,ax = plt.subplots(figsize=(16,9))
ax.bar(df_month['2016':].index, df_month.loc['2016':,'Volume'], width=25, align='center')
# Out:
# <BarContainer object of 24 artists>

# %%
df.Low.diff(2).plot(figsize=(16,9))
# Out:
# <Axes: xlabel='Date'>

# %%
df.High.diff(2).plot(figsize=(16,9))
# Out:
# <Axes: xlabel='Date'>

# %%
window_size = 50
rolling_mean = df['Open'].rolling(window_size).mean()
rolling_mean.plot()
# Out:
# <Axes: xlabel='Date'>
